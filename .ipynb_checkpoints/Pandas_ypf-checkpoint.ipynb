# %%
import pandas

# %%
archivo=pandas.read_csv('dataset_evaluacion.csv')

# %%
archivo.head()
# Out:
#    ID_FILA           ID_EVENTO    CAMPO FLUIDO PAD_HIJO      HIJO  ETAPA_HIJO  \
# 0    26179  Pozo 27-Pozo 54-38  Campo B    OIL   PAD-13   Pozo 27          38
# 1    26180  Pozo 29-Pozo 54-39  Campo B    OIL   PAD-13   Pozo 29          39
# 2    26181  Pozo 27-Pozo 54-41  Campo B    OIL   PAD-13   Pozo 27          41
# 3    26182  Pozo 555-Pozo 69-4  Campo E    OIL   PAD-85  Pozo 555           4
# 4    26183  Pozo 555-Pozo 69-5  Campo E    OIL   PAD-85  Pozo 555           5
#
#      PADRE               D3D               D2D                 DZ  \
# 0  Pozo 54  1583,88765604514  1583,66685325096  -26,4462641286172
# 1  Pozo 54  1477,04069824078  1476,93067008705   18,0283115076863
# 2  Pozo 54  1445,96318312391  1445,75039944171  -24,8054321466424
# 3  Pozo 69  672,288788400604  672,248439433554   7,36550665623372
# 4  Pozo 69  642,817439643753  642,776547895096   7,25053006430698
#
#                  AZ  #_BARRERAS LINEAMIENTO WHP_i   ESTADO
# ...

# %%
archivo.index
# Out:
# RangeIndex(start=0, stop=6537, step=1)

# %%
archivo.columns
# Out:
# Index(['ID_FILA', 'ID_EVENTO', 'CAMPO', 'FLUIDO', 'PAD_HIJO', 'HIJO',
#        'ETAPA_HIJO', 'PADRE', 'D3D', 'D2D', 'DZ', 'AZ', '#_BARRERAS',
#        'LINEAMIENTO', 'WHP_i', 'ESTADO'],
#       dtype='object')

# %%
archivo.values
# Out:
# array([[26179, 'Pozo 27-Pozo 54-38', 'Campo B', ..., 'NO', '-0,3',
#         'Cerrado'],
#        [26180, 'Pozo 29-Pozo 54-39', 'Campo B', ..., 'NO', '-0,3',
#         'Cerrado'],
#        [26181, 'Pozo 27-Pozo 54-41', 'Campo B', ..., 'NO', '-0,3',
#         'Cerrado'],
#        ...,
#        [32713, 'Pozo 549-Pozo 210-24', 'Campo E', ..., 'SI', '368',
#         'Cerrado'],
#        [32714, 'Pozo 557-Pozo 404-33', 'Campo E', ..., 'SI', '368,9',
#         'Cerrado'],
#        [32715, 'Pozo 552-Pozo 404-24', 'Campo E', ..., 'SI', '371,8',
#         'Cerrado']], dtype=object)

# %%
archivo
# Out:
#       ID_FILA             ID_EVENTO    CAMPO FLUIDO PAD_HIJO      HIJO  \
# 0       26179    Pozo 27-Pozo 54-38  Campo B    OIL   PAD-13   Pozo 27
# 1       26180    Pozo 29-Pozo 54-39  Campo B    OIL   PAD-13   Pozo 29
# 2       26181    Pozo 27-Pozo 54-41  Campo B    OIL   PAD-13   Pozo 27
# 3       26182    Pozo 555-Pozo 69-4  Campo E    OIL   PAD-85  Pozo 555
# 4       26183    Pozo 555-Pozo 69-5  Campo E    OIL   PAD-85  Pozo 555
# ...       ...                   ...      ...    ...      ...       ...
# 6532    32711  Pozo 316-Pozo 323-24  Campo E    OIL   PAD-72  Pozo 316
# 6533    32712  Pozo 553-Pozo 404-25  Campo E    OIL   PAD-85  Pozo 553
# 6534    32713  Pozo 549-Pozo 210-24  Campo E    OIL   PAD-84  Pozo 549
# 6535    32714  Pozo 557-Pozo 404-33  Campo E    OIL   PAD-85  Pozo 557
# 6536    32715  Pozo 552-Pozo 404-24  Campo E    OIL   PAD-85  Pozo 552
#
#       ETAPA_HIJO     PADRE               D3D               D2D  \
# ...

# %%
archivo.columns
# Out:
# Index(['ID_FILA', 'ID_EVENTO', 'CAMPO', 'FLUIDO', 'PAD_HIJO', 'HIJO',
#        'ETAPA_HIJO', 'PADRE', 'D3D', 'D2D', 'DZ', 'AZ', '#_BARRERAS',
#        'LINEAMIENTO', 'WHP_i', 'ESTADO'],
#       dtype='object')

# %%
archivo.ID_FILA
# Out:
# 0       26179
# 1       26180
# 2       26181
# 3       26182
# 4       26183
#         ...
# 6532    32711
# 6533    32712
# 6534    32713
# 6535    32714
# 6536    32715
# Name: ID_FILA, Length: 6537, dtype: int64

# %%
archivo.columns
# Out:
# Index(['ID_FILA', 'ID_EVENTO', 'CAMPO', 'FLUIDO', 'PAD_HIJO', 'HIJO',
#        'ETAPA_HIJO', 'PADRE', 'D3D', 'D2D', 'DZ', 'AZ', '#_BARRERAS',
#        'LINEAMIENTO', 'WHP_i', 'ESTADO'],
#       dtype='object')

# %%
archivo[archivo["ESTADO"]=="Abierto"]
# Out:
#       ID_FILA             ID_EVENTO    CAMPO FLUIDO PAD_HIJO      HIJO  \
# 8       26187  Pozo 132-Pozo 112-15  Campo C    GAS   PAD-19  Pozo 132
# 9       26188  Pozo 133-Pozo 112-16  Campo C    GAS   PAD-19  Pozo 133
# 22      26201  Pozo 121-Pozo 112-12  Campo C    GAS   PAD-19  Pozo 121
# 23      26202  Pozo 122-Pozo 112-12  Campo C    GAS   PAD-19  Pozo 122
# 24      26203  Pozo 122-Pozo 112-13  Campo C    GAS   PAD-19  Pozo 122
# ...       ...                   ...      ...    ...      ...       ...
# 6517    32696   Pozo 387-Pozo 245-5  Campo F    OIL   PAD-60  Pozo 387
# 6518    32697   Pozo 408-Pozo 245-2  Campo F    OIL   PAD-60  Pozo 408
# 6527    32706   Pozo 405-Pozo 243-9  Campo F    OIL   PAD-60  Pozo 405
# 6530    32709   Pozo 407-Pozo 244-2  Campo F    OIL   PAD-60  Pozo 407
# 6531    32710   Pozo 407-Pozo 244-3  Campo F    OIL   PAD-60  Pozo 407
#
#       ETAPA_HIJO     PADRE               D3D               D2D  \
# ...

# %%
archivo.isna().sum()
# Out:
# ID_FILA         0
# ID_EVENTO       0
# CAMPO           0
# FLUIDO         56
# PAD_HIJO        0
# HIJO            0
# ETAPA_HIJO      0
# PADRE           0
# D3D             0
# D2D             0
# DZ              0
# AZ              0
# #_BARRERAS      0
# LINEAMIENTO     0
# WHP_i           0
# ESTADO          0
# dtype: int64

# %%
archivo.index
# Out:
# RangeIndex(start=0, stop=6537, step=1)

# %%
archivo[archivo['ID_FILA'] > 2800]
# Out:
#       ID_FILA             ID_EVENTO    CAMPO FLUIDO PAD_HIJO      HIJO  \
# 0       26179    Pozo 27-Pozo 54-38  Campo B    OIL   PAD-13   Pozo 27
# 1       26180    Pozo 29-Pozo 54-39  Campo B    OIL   PAD-13   Pozo 29
# 2       26181    Pozo 27-Pozo 54-41  Campo B    OIL   PAD-13   Pozo 27
# 3       26182    Pozo 555-Pozo 69-4  Campo E    OIL   PAD-85  Pozo 555
# 4       26183    Pozo 555-Pozo 69-5  Campo E    OIL   PAD-85  Pozo 555
# ...       ...                   ...      ...    ...      ...       ...
# 6532    32711  Pozo 316-Pozo 323-24  Campo E    OIL   PAD-72  Pozo 316
# 6533    32712  Pozo 553-Pozo 404-25  Campo E    OIL   PAD-85  Pozo 553
# 6534    32713  Pozo 549-Pozo 210-24  Campo E    OIL   PAD-84  Pozo 549
# 6535    32714  Pozo 557-Pozo 404-33  Campo E    OIL   PAD-85  Pozo 557
# 6536    32715  Pozo 552-Pozo 404-24  Campo E    OIL   PAD-85  Pozo 552
#
#       ETAPA_HIJO     PADRE               D3D               D2D  \
# ...
